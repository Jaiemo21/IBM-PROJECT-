# %% [markdown]
# <a href="https://colab.research.google.com/github/Jaiemo21/IBM-PROJECT-/blob/main/Assignment%201.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q kaggle

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-341fa1a8-af72-4424-9c17-2a2a792a20b6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-341fa1a8-af72-4424-9c17-2a2a792a20b6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
! cp kaggle.json ~/.kaggle/

# %%
! chmod 600 ~/.kaggle/kaggle.json

# %%
! kaggle datasets download -d mohamedafsal007/house-price-dataset-of-india
# Out:
# ...
# 100% 480k/480k [00:00<00:00, 1.19MB/s]
# 100% 480k/480k [00:00<00:00, 1.19MB/s]

# %%
! unzip /content/house-price-dataset-of-india
# Out:
# Archive:  /content/house-price-dataset-of-india.zip
#   inflating: House Price India.csv

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sriram =pd.read_csv('/content/House Price India.csv')

# %%
sriram.columns
# Out:
# Index(['id', 'Date', 'number of bedrooms', 'number of bathrooms',
#        'living area', 'lot area', 'number of floors', 'waterfront present',
#        'number of views', 'condition of the house', 'grade of the house',
#        'Area of the house(excluding basement)', 'Area of the basement',
#        'Built Year', 'Renovation Year', 'Postal Code', 'Lattitude',
#        'Longitude', 'living_area_renov', 'lot_area_renov',
#        'Number of schools nearby', 'Distance from the airport', 'Price'],
#       dtype='object')

# %%
sriram.head( )
# Out:
#            id   Date  number of bedrooms  number of bathrooms  living area  \
# 0  6762810145  42491                   5                 2.50         3650
# 1  6762810635  42491                   4                 2.50         2920
# 2  6762810998  42491                   5                 2.75         2910
# 3  6762812605  42491                   4                 2.50         3310
# 4  6762812919  42491                   3                 2.00         2710
#
#    lot area  number of floors  waterfront present  number of views  \
# 0      9050               2.0                   0                4
# 1      4000               1.5                   0                0
# 2      9480               1.5                   0                0
# 3     42998               2.0                   0                0
# 4      4500               1.5                   0                0
#
#    condition of the house  ...  Built Year  Renovation Year  Postal Code  \
# ...

# %%
sriram.tail( )
# Out:
#                id   Date  number of bedrooms  number of bathrooms  \
# 14615  6762830250  42734                   2                  1.5
# 14616  6762830339  42734                   3                  2.0
# 14617  6762830618  42734                   2                  1.0
# 14618  6762830709  42734                   4                  1.0
# 14619  6762831463  42734                   3                  1.0
#
#        living area  lot area  number of floors  waterfront present  \
# 14615         1556     20000               1.0                   0
# 14616         1680      7000               1.5                   0
# 14617         1070      6120               1.0                   0
# 14618         1030      6621               1.0                   0
# 14619          900      4770               1.0                   0
#
#        number of views  condition of the house  ...  Built Year  \
# 14615                0                       4  ...        1957
# ...

# %%
sriram.dtypes
# Out:
# id                                         int64
# Date                                       int64
# number of bedrooms                         int64
# number of bathrooms                      float64
# living area                                int64
# lot area                                   int64
# number of floors                         float64
# waterfront present                         int64
# number of views                            int64
# condition of the house                     int64
# grade of the house                         int64
# Area of the house(excluding basement)      int64
# Area of the basement                       int64
# Built Year                                 int64
# Renovation Year                            int64
# Postal Code                                int64
# Lattitude                                float64
# Longitude                                float64
# living_area_renov                          int64
# ...

# %%
sriram.shape
# Out:
# (14620, 23)

# %%
sriram.describe
# Out:
# <bound method NDFrame.describe of                id   Date  number of bedrooms  number of bathrooms  \
# 0      6762810145  42491                   5                 2.50
# 1      6762810635  42491                   4                 2.50
# 2      6762810998  42491                   5                 2.75
# 3      6762812605  42491                   4                 2.50
# 4      6762812919  42491                   3                 2.00
# ...           ...    ...                 ...                  ...
# 14615  6762830250  42734                   2                 1.50
# 14616  6762830339  42734                   3                 2.00
# 14617  6762830618  42734                   2                 1.00
# 14618  6762830709  42734                   4                 1.00
# 14619  6762831463  42734                   3                 1.00
#
#        living area  lot area  number of floors  waterfront present  \
# 0             3650      9050               2.0                   0
# ...

# %%
sriram.info( )
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14620 entries, 0 to 14619
# Data columns (total 23 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     14620 non-null  int64
#  1   Date                                   14620 non-null  int64
#  2   number of bedrooms                     14620 non-null  int64
#  3   number of bathrooms                    14620 non-null  float64
#  4   living area                            14620 non-null  int64
#  5   lot area                               14620 non-null  int64
#  6   number of floors                       14620 non-null  float64
#  7   waterfront present                     14620 non-null  int64
#  8   number of views                        14620 non-null  int64
#  9   condition of the house                 14620 non-null  int64
# ...

# %%
sriram.id.is_unique
# Out:
# True

# %%
sriram.set_index('id',inplace=True)

# %%
sriram.head()
# Out:
#              Date  number of bedrooms  number of bathrooms  living area  \
# id
# 6762810145  42491                   5                 2.50         3650
# 6762810635  42491                   4                 2.50         2920
# 6762810998  42491                   5                 2.75         2910
# 6762812605  42491                   4                 2.50         3310
# 6762812919  42491                   3                 2.00         2710
#
#             lot area  number of floors  waterfront present  number of views  \
# id
# 6762810145      9050               2.0                   0                4
# 6762810635      4000               1.5                   0                0
# 6762810998      9480               1.5                   0                0
# 6762812605     42998               2.0                   0                0
# 6762812919      4500               1.5                   0                0
#
# ...

# %%
sriram.nunique()
# Out:
# Date                                      241
# number of bedrooms                         12
# number of bathrooms                        29
# living area                               865
# lot area                                 7451
# number of floors                            6
# waterfront present                          2
# number of views                             5
# condition of the house                      5
# grade of the house                         10
# Area of the house(excluding basement)     781
# Area of the basement                      280
# Built Year                                116
# Renovation Year                            68
# Postal Code                                70
# Lattitude                                4662
# Longitude                                 716
# living_area_renov                         665
# lot_area_renov                           6835
# Number of schools nearby                    3
# ...

# %%
sriram.isnull()
# Out:
#              Date  number of bedrooms  number of bathrooms  living area  \
# id
# 6762810145  False               False                False        False
# 6762810635  False               False                False        False
# 6762810998  False               False                False        False
# 6762812605  False               False                False        False
# 6762812919  False               False                False        False
# ...           ...                 ...                  ...          ...
# 6762830250  False               False                False        False
# 6762830339  False               False                False        False
# 6762830618  False               False                False        False
# 6762830709  False               False                False        False
# 6762831463  False               False                False        False
#
#             lot area  number of floors  waterfront present  number of views  \
# id
# ...

# %%
sriram.isnull().sum()
# Out:
# Date                                     0
# number of bedrooms                       0
# number of bathrooms                      0
# living area                              0
# lot area                                 0
# number of floors                         0
# waterfront present                       0
# number of views                          0
# condition of the house                   0
# grade of the house                       0
# Area of the house(excluding basement)    0
# Area of the basement                     0
# Built Year                               0
# Renovation Year                          0
# Postal Code                              0
# Lattitude                                0
# Longitude                                0
# living_area_renov                        0
# lot_area_renov                           0
# Number of schools nearby                 0
# Distance from the airport                0
# Price                                    0
# ...

# %% [markdown]
# UNIVARIABLE ANALYSIS

# %%
sns.countplot(data=sriram,x='Distance from the airport')
# Out:
# <Axes: xlabel='Distance from the airport', ylabel='count'>

# %%
sns.countplot(data=sriram,x='Postal Code')
# Out:
# <Axes: xlabel='Postal Code', ylabel='count'>

# %%
sns.countplot(data=sriram,x='number of bedrooms')
# Out:
# <Axes: xlabel='number of bedrooms', ylabel='count'>

# %%
sns.countplot(data=sriram,x='number of bathrooms')
# Out:
# <Axes: xlabel='number of bathrooms', ylabel='count'>

# %% [markdown]
# BIVARIATE ANALYSIS

# %%
sns.lineplot(data=sriram,x='Distance from the airport',y='Price')
# Out:
# <Axes: xlabel='Distance from the airport', ylabel='Price'>

# %%
sns.regplot(data=sriram,x='Postal Code',y='Price')
# Out:
# <Axes: xlabel='Postal Code', ylabel='Price'>

# %%
sns.boxplot(data=sriram,x='Built Year',y='Price')
# Out:
# <Axes: xlabel='Built Year', ylabel='Price'>

# %% [markdown]
# MULTIVARIABLE ANALYSIS

# %%
sns.heatmap(sriram.corr())
# Out:
# <Axes: >

# %%
sns.pairplot(sriram)

# %%
sns.rugplot(x='Date',data=sriram,height=0.05,color='blue')
sns.histplot(x='Date',data=sriram,kde=True)
# Out:
# <Axes: xlabel='Date', ylabel='Count'>
